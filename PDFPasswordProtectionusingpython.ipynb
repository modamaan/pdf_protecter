# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\amaan\anaconda3\lib\site-packages (3.0.1)

# %%
from PyPDF2 import PdfReader, PdfWriter

# %%
## open the current pdf
file_pdf = PdfReader('data.pdf')
### Object for pdf writer
out_pdf = PdfWriter()

# %%
len(file_pdf.pages)
# Out:
# 9

# %%
file_pdf

# %%
for i in range(len(file_pdf.pages)):
    page_details = file_pdf.pages[i]
    ## add to output page
out_pdf.add_page(page_details)
# Out:
# {'/Contents': [IndirectObject(5, 0, 1890102306320)],
#  '/CropBox': [0, 0, 612, 792],
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/Font': {'/F1': {'/BaseFont': '/CIDFont+F1',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F1',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 952,
#        '/CapHeight': 631,
#        '/Descent': -268,
#        '/Flags': 6,
#        '/FontBBox': [-506, -268, 506, 952],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 565300,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F1',
#        '/ItalicAngle': 0,
#        '/StemV': 506,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [3,
#        3,
#        226,
#        1005,
#        1005,
#        506,
#        1006,
#        1006,
#        506,
#        1007,
#        1007,
#        506,
#        1008,
#        1008,
#        506,
#        1009,
#        1009,
#        506,
#        1010,
#        1010,
#        506,
#        1011,
#        1011,
#        506,
#        1012,
#        1012,
#        506,
#        1013,
#        1013,
#        506]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F2': {'/BaseFont': '/CIDFont+F2',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F2',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 952,
#        '/CapHeight': 631,
#        '/Descent': -268,
#        '/Flags': 6,
#        '/FontBBox': [-537, -268, 537, 952],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 543560,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F2',
#        '/ItalicAngle': 0,
#        '/StemV': 537,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [3,
#        3,
#        226,
#        258,
#        258,
#        493,
#        271,
#        271,
#        536,
#        272,
#        272,
#        418,
#        282,
#        282,
#        536,
#        286,
#        286,
#        503,
#        349,
#        349,
#        245,
#        381,
#        381,
#        537,
#        400,
#        400,
#        398,
#        856,
#        856,
#        267]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F3': {'/BaseFont': '/CIDFont+F9',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F9',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 832,
#        '/CapHeight': 571,
#        '/Descent': -300,
#        '/Flags': 6,
#        '/FontBBox': [-600, -300, 600, 832],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 100540,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F9',
#        '/ItalicAngle': 0,
#        '/StemV': 600,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [82, 82, 600]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F4': {'/BaseFont': '/CIDFont+F8',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F8',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 905,
#        '/CapHeight': 716,
#        '/Descent': -211,
#        '/Flags': 6,
#        '/FontBBox': [-277, -211, 277, 905],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 349872,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F8',
#        '/ItalicAngle': 0,
#        '/StemV': 277,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [3, 3, 277]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F5': {'/BaseFont': '/CIDFont+F4',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F4',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 1079,
#        '/CapHeight': 700,
#        '/Descent': -250,
#        '/Flags': 6,
#        '/FontBBox': [-934, -250, 934, 1079],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 333820,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F4',
#        '/ItalicAngle': 0,
#        '/StemV': 934,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [3,
#        3,
#        273,
#        11,
#        11,
#        301,
#        12,
#        12,
#        301,
#        14,
#        14,
#        684,
#        15,
#        15,
#        216,
#        16,
#        16,
#        399,
#        17,
#        17,
#        216,
#        18,
#        18,
#        389,
#        19,
#        19,
#        539,
#        20,
#        20,
#        539,
#        21,
#        21,
#        539,
#        22,
#        22,
#        539,
#        23,
#        23,
#        539,
#        24,
#        24,
#        539,
#        25,
#        25,
#        539,
#        26,
#        26,
#        539,
#        27,
#        27,
#        539,
#        28,
#        28,
#        539,
#        29,
#        29,
#        216,
#        32,
#        32,
#        684,
#        34,
#        34,
#        448,
#        36,
#        36,
#        645,
#        37,
#        37,
#        573,
#        38,
#        38,
#        619,
#        39,
#        39,
#        701,
#        40,
#        40,
#        505,
#        41,
#        41,
#        488,
#        42,
#        42,
#        686,
#        43,
#        43,
#        709,
#        44,
#        44,
#        266,
#        45,
#        45,
#        356,
#        46,
#        46,
#        580,
#        47,
#        47,
#        470,
#        48,
#        48,
#        897,
#        49,
#        49,
#        748,
#        50,
#        50,
#        753,
#        51,
#        51,
#        560,
#        52,
#        52,
#        753,
#        53,
#        53,
#        598,
#        54,
#        54,
#        531,
#        55,
#        55,
#        523,
#        56,
#        56,
#        687,
#        57,
#        57,
#        621,
#        58,
#        58,
#        934,
#        59,
#        59,
#        589,
#        60,
#        60,
#        552,
#        61,
#        61,
#        570,
#        68,
#        68,
#        508,
#        69,
#        69,
#        587,
#        70,
#        70,
#        461,
#        71,
#        71,
#        588,
#        72,
#        72,
#        522,
#        73,
#        73,
#        312,
#        74,
#        74,
#        588,
#        75,
#        75,
#        565,
#        76,
#        76,
#        242,
#        77,
#        77,
#        242,
#        78,
#        78,
#        497,
#        79,
#        79,
#        242,
#        80,
#        80,
#        861,
#        81,
#        81,
#        565,
#        82,
#        82,
#        585,
#        83,
#        83,
#        587,
#        84,
#        84,
#        588,
#        85,
#        85,
#        347,
#        86,
#        86,
#        424,
#        87,
#        87,
#        338,
#        88,
#        88,
#        565,
#        89,
#        89,
#        479,
#        90,
#        90,
#        722,
#        91,
#        91,
#        458,
#        92,
#        92,
#        483,
#        93,
#        93,
#        452,
#        172,
#        172,
#        732,
#        183,
#        183,
#        229]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F6': {'/BaseFont': '/CIDFont+F3',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F3',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 1079,
#        '/CapHeight': 700,
#        '/Descent': -250,
#        '/Flags': 6,
#        '/FontBBox': [-1004, -250, 1004, 1079],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 352956,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F3',
#        '/ItalicAngle': 0,
#        '/StemV': 1004,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [3,
#        3,
#        275,
#        11,
#        11,
#        369,
#        12,
#        12,
#        369,
#        15,
#        15,
#        270,
#        16,
#        16,
#        404,
#        17,
#        17,
#        270,
#        18,
#        18,
#        443,
#        19,
#        19,
#        575,
#        20,
#        20,
#        575,
#        21,
#        21,
#        575,
#        22,
#        22,
#        575,
#        23,
#        23,
#        575,
#        24,
#        24,
#        575,
#        25,
#        25,
#        575,
#        26,
#        26,
#        575,
#        27,
#        27,
#        575,
#        28,
#        28,
#        575,
#        29,
#        29,
#        270,
#        34,
#        34,
#        437,
#        36,
#        36,
#        703,
#        37,
#        37,
#        641,
#        38,
#        38,
#        624,
#        39,
#        39,
#        737,
#        41,
#        41,
#        520,
#        42,
#        42,
#        710,
#        44,
#        44,
#        316,
#        46,
#        46,
#        648,
#        47,
#        47,
#        511,
#        48,
#        48,
#        957,
#        49,
#        49,
#        790,
#        50,
#        50,
#        758,
#        51,
#        51,
#        614,
#        52,
#        52,
#        758,
#        53,
#        53,
#        652,
#        54,
#        54,
#        560,
#        55,
#        55,
#        585,
#        57,
#        57,
#        666,
#        58,
#        58,
#        1004,
#        68,
#        68,
#        538,
#        69,
#        69,
#        620,
#        70,
#        70,
#        479,
#        71,
#        71,
#        619,
#        72,
#        72,
#        541,
#        73,
#        73,
#        383,
#        74,
#        74,
#        619,
#        75,
#        75,
#        602,
#        76,
#        76,
#        284,
#        77,
#        77,
#        284,
#        78,
#        78,
#        559,
#        79,
#        79,
#        284,
#        80,
#        80,
#        916,
#        81,
#        81,
#        604,
#        82,
#        82,
#        611,
#        83,
#        83,
#        620,
#        85,
#        85,
#        397,
#        86,
#        86,
#        439,
#        87,
#        87,
#        389,
#        88,
#        88,
#        604,
#        89,
#        89,
#        541,
#        90,
#        90,
#        797,
#        92,
#        92,
#        538,
#        93,
#        93,
#        479,
#        172,
#        172,
#        912]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'},
#    '/F7': {'/BaseFont': '/CIDFont+F7',
#     '/DescendantFonts': [{'/BaseFont': '/CIDFont+F7',
#       '/CIDSystemInfo': {'/Ordering': 'Identity',
#        '/Registry': 'Adobe',
#        '/Supplement': 0},
#       '/CIDToGIDMap': '/Identity',
#       '/FontDescriptor': {'/Ascent': 1005,
#        '/CapHeight': 699,
#        '/Descent': -219,
#        '/Flags': 6,
#        '/FontBBox': [-459, -219, 459, 1005],
#        '/FontFile2': {'/Filter': '/FlateDecode',
#         '/Length1': 23900,
#         '/Type': '/Stream'},
#        '/FontName': '/CIDFont+F7',
#        '/ItalicAngle': 0,
#        '/StemV': 459,
#        '/Type': '/FontDescriptor'},
#       '/Subtype': '/CIDFontType2',
#       '/Type': '/Font',
#       '/W': [120, 120, 459]}],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {},
#     '/Type': '/Font'}},
#   '/XObject': {'/Image1': {'/BitsPerComponent': 8,
#     '/ColorSpace': '/DeviceGray',
#     '/Filter': '/FlateDecode',
#     '/Height': 63,
#     '/Subtype': '/Image',
#     '/Type': '/XObject',
#     '/Width': 143}}},
#  '/Rotate': 0,
#  '/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 1,
#   '/Kids': [IndirectObject(4, 0, 1890102306320)]}}

# %%
len(page_details)
# Out:
# 7

# %%
password = 'amaan123'

out_pdf.encrypt(password)

# %%
with open("encryptedDATA1.pdf","wb") as filename:
    out_pdf.write(filename)
